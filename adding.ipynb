# %%
import pandas as pd 

data = {

  "Name":['Inam','Osama','Jabir','Sakib','Mokit','Rehan','Tanvir'],
  "Age":[21,23,24,18,14,12,8],
  "Salary":[100000,300000,500000,6000000,70000000,4000000,900000],
  "Proformance Score":[90,50,60,40,80,70,66]

 }

df = pd.DataFrame(data)

print(df)
#assigment operator 
df["Bonus"] = df['Salary'] * 0.1
print(df)

#using insert() method
#df.insert(location,"Column_Name",Some_date)
df.insert(0,"Employee ID",[10,20,30,40,50,60,70])
df.insert(6, "Employee Address", ['kopa','Chhapra','Siwan','Patna','Delhi','Mumbai','Bangalore'])
df.inser(7,"em")



print(df)
# Out:
#      Name  Age    Salary  Proformance Score
# 0    Inam   21    100000                 90
# 1   Osama   23    300000                 50
# 2   Jabir   24    500000                 60
# 3   Sakib   18   6000000                 40
# 4   Mokit   14  70000000                 80
# 5   Rehan   12   4000000                 70
# 6  Tanvir    8    900000                 66
#      Name  Age    Salary  Proformance Score      Bonus
# 0    Inam   21    100000                 90    10000.0
# 1   Osama   23    300000                 50    30000.0
# 2   Jabir   24    500000                 60    50000.0
# 3   Sakib   18   6000000                 40   600000.0
# 4   Mokit   14  70000000                 80  7000000.0
# 5   Rehan   12   4000000                 70   400000.0
# 6  Tanvir    8    900000                 66    90000.0
#    Employee ID    Name  Age    Salary  Proformance Score      Bonus  \
# 0           10    Inam   21    100000                 90    10000.0
# 1           20   Osama   23    300000                 50    30000.0
# 2           30   Jabir   24    500000                 60    50000.0
# 3           40   Sakib   18   6000000                 40   600000.0
# 4           50   Mokit   14  70000000                 80  7000000.0
# 5           60   Rehan   12   4000000                 70   400000.0
# 6           70  Tanvir    8    900000                 66    90000.0
#
#   Employee Address    Branch
# 0             kopa       CSE
# 1          Chhapra  Teaching
# 2            Siwan     ababf
# 3            Patna   fheuibf
# 4            Delhi    hujhge
# 5           Mumbai    fabefb
# 6        Bangalore     hfgeg
