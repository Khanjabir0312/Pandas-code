# %%
#Describe method in pandas,its very powerfull tool that you to 
# will provide a summary of descriptive statistics for Numerical
# columns in your data frame.

#step-1 sample data frame
import pandas as pd
data = {
  "Name":['Inam','Osama','Jabir','Sakib','Mokit','Rehan','Tanvir'],
  "Age":[21,23,24,18,14,12,8],
  "Salary":[100000,300000,500000,6000000,70000000,4000000,900000],
  "Proformance Score":[90,50,60,40,80,70,66]

 }

df = pd.DataFrame(data)
print("Sample DataFrame")
print(df)

#step-2 describe the data
print('Descriptive Statistics')
print(df.describe())
# Out:
# Sample DataFrame
#      Name  Age    Salary  Proformance Score
# 0    Inam   21    100000                 90
# 1   Osama   23    300000                 50
# 2   Jabir   24    500000                 60
# 3   Sakib   18   6000000                 40
# 4   Mokit   14  70000000                 80
# 5   Rehan   12   4000000                 70
# 6  Tanvir    8    900000                 66
# Descriptive Statistics
#              Age        Salary  Proformance Score
# count   7.000000  7.000000e+00           7.000000
# mean   17.142857  1.168571e+07          65.142857
# std     6.011893  2.581107e+07          17.082433
# min     8.000000  1.000000e+05          40.000000
# 25%    13.000000  4.000000e+05          55.000000
# 50%    18.000000  9.000000e+05          66.000000
# 75%    22.000000  5.000000e+06          75.000000
# max    24.000000  7.000000e+07          90.000000
