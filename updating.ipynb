# %%
import pandas as pd 

data = {

  "Name":['Inam','Osama','Jabir','Sakib','Mokit','Rehan','Tanvir'],
  "Age":[21,23,24,18,14,12,8],
  "Salary":[100000,300000,500000,6000000,70000000,4000000,900000],
  "Proformance Score":[90,50,60,40,80,70,66]

 }

df = pd.DataFrame(data)

print(df)

#updating method
#df.loc[row_index,"Column Name"] = new_value
df.loc[0,'Salary'] = 5000
print(df)
# Out:
#      Name  Age    Salary  Proformance Score
# 0    Inam   21    100000                 90
# 1   Osama   23    300000                 50
# 2   Jabir   24    500000                 60
# 3   Sakib   18   6000000                 40
# 4   Mokit   14  70000000                 80
# 5   Rehan   12   4000000                 70
# 6  Tanvir    8    900000                 66
#      Name  Age    Salary  Proformance Score
# 0    Inam   21      5000                 90
# 1   Osama   23    300000                 50
# 2   Jabir   24    500000                 60
# 3   Sakib   18   6000000                 40
# 4   Mokit   14  70000000                 80
# 5   Rehan   12   4000000                 70
# 6  Tanvir    8    900000                 66

# %%
import pandas as pd 

data = {

  "Name":['Inam','Osama','Jabir','Sakib','Mokit','Rehan','Tanvir'],
  "Age":[21,23,24,18,14,12,8],
  "Salary":[100000,300000,500000,6000000,70000000,4000000,900000],
  "Proformance Score":[90,50,60,40,80,70,66]

 }
df=pd.DataFrame(data)
print(df)
#increasing salary by 5%
df['Salary'] = df['Salary'] * 1.05

 ?

jb kkmnjkljlnjk klm ?
print(df)
# Out:
#      Name  Age    Salary  Proformance Score
# 0    Inam   21    100000                 90
# 1   Osama   23    300000                 50
# 2   Jabir   24    500000                 60
# 3   Sakib   18   6000000                 40
# 4   Mokit   14  70000000                 80
# 5   Rehan   12   4000000                 70
# 6  Tanvir    8    900000                 66
#      Name  Age      Salary  Proformance Score
# 0    Inam   21    105000.0                 90
# 1   Osama   23    315000.0                 50
# 2   Jabir   24    525000.0                 60
# 3   Sakib   18   6300000.0                 40
# 4   Mokit   14  73500000.0                 80
# 5   Rehan   12   4200000.0                 70
# 6  Tanvir    8    945000.0                 66
