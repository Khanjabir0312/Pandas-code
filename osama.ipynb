# %%
# import pandas as pd

# data={
#     "Name":['Inam','Mokit','Sakib'],
#     "Age":[10,20,30],
#     "City":['Delhi','Panta','Siwan']
# }

# df = pd.DataFrame(data)
# print(df)

# df.to_csv("output.csv",index=False) 
# df.to_excel("output.xlsx", index=False)
# df.to_json("output.josn", index=False)

import pandas as  pd 
data={
    "Name":['Inam','Mokit','Sakib','Rehan'],
    "Age":[10,30,59,30],
    "city":['Delhi','Mumbai','Bihar','Banglore']
}
df = pd.DataFrame(data)
print('Display the info of data set')
print(df.info())#data ka information ke liye
# Out:
# Display the info of data set
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Age     4 non-null      int64
#  2   city    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes
# None
