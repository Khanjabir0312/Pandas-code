# %%
# df["Column Name"].mean()
# df["Column Name"].Sum()
# df["Column Name"].min()
# df["Column Name"].max()

import pandas as pd

data = {
    "Name":['Inam','Osama','Jabir'],
     "Age":[28,34,22],
     "Salary":[10000,20000,30000]
}

df=pd.DataFrame(data)

avg_salary=df['Salary'].min()
print(avg_salary)
# Out:
# 10000
